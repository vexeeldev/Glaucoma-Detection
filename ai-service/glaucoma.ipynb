# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing import image
import os
from tensorflow.keras.applications import EfficientNetB0

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Success: Memory Growth diaktifkan untuk GPU.")
    except RuntimeError as e:
        print(f"Error pada konfigurasi GPU: {e}")

# %%
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# eyepac-light-v2-512-jpg
img_size = (224, 224)
batch_size = 16

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2), # Putar lebih jauh
    layers.RandomZoom(0.2),     # Zoom lebih dalam
    layers.RandomContrast(0.2), # Mainkan kontras biar saraf kelihatan
])

train_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/train",
    image_size=img_size,
    batch_size=batch_size,
    label_mode="int"
).map(lambda x, y: (data_augmentation(x, training=True), y)).prefetch(tf.data.AUTOTUNE)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/validation",
    image_size=img_size,
    batch_size=batch_size,
    label_mode="int"
).prefetch(tf.data.AUTOTUNE)

# train_ds = tf.keras.utils.image_dataset_from_directory(
#     "dataset/train",
#     image_size=img_size,
#     batch_size=batch_size,
#     label_mode="int"  # karena 0 dan 1
# )

# val_ds = tf.keras.utils.image_dataset_from_directory(
#     "dataset/validation",
#     image_size=img_size,
#     batch_size=batch_size,
#     label_mode="int"
# )
# Out:
# Found 25778 files belonging to 2 classes.
# Found 1498 files belonging to 2 classes.

# %%
print("Class names:", train_ds)
# Out:
# Class names: <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# 3. TAMBAHKAN LAYER AUGMENTASI (Bumbu Rahasia)
# data_augmentation = tf.keras.Sequential([
#   layers.RandomFlip("horizontal"),
#   layers.RandomRotation(0.1),
#   layers.RandomZoom(0.1),
# ])

# %%
# normalization_layer = layers.Rescaling(1./255)

# train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
# normalization_layer = layers.Rescaling(1./255)

# train_ds = train_ds.map(lambda x, y: (normalization_layer(data_augmentation(x, training=True)), y))
# val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# # Optimasi memori biar MX450 makin kencang
# train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
# val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# base_model = tf.keras.applications.MobileNetV2(
#     input_shape=(224, 224, 3),
#     include_top=False,
#     weights="imagenet"
# )

# base_model.trainable = False  

# model = keras.Sequential([
#     base_model,
#     layers.GlobalAveragePooling2D(),
#     layers.Dense(128, activation="relu"),
#     layers.Dropout(0.3),
#     layers.Dense(1, activation="sigmoid")  # binary classification
# ])
base_model = EfficientNetB0(
    input_shape=(224, 224, 3), 
    include_top=False, 
    weights="imagenet"
)
base_model.trainable = True  


model = tf.keras.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(), # Penting buat EfficientNet biar stabil
    layers.Dropout(0.4),         # Mengurangi risiko overfitting
    layers.Dense(1, activation="sigmoid", dtype='float32') 
])

# %%
# model.compile(
#     optimizer="adam",
#     loss="binary_crossentropy",
#     metrics=["accuracy"]
# )
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4), 
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Recall(name="recall")]
)

# %%
# history = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=10
# )
# 1. Callback tanpa checkpoint (gak pake simpan file dulu)
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2, 
    patience=2, 
    min_lr=1e-7,
    verbose=1
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True
)


class_weights = {0: 1.0, 1: 1.5}

print("\n--- Memulai Mode Brutal: EfficientNetB0 + Class Weights (Tanpa Simpan) ---")

# 3. Jalankan Fit
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15, 
    callbacks=[lr_reducer, early_stop],
    class_weight=class_weights
)
# Out:
# --- Memulai Mode Brutal: EfficientNetB0 + Class Weights (Tanpa Simpan) ---
# Epoch 1/15
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 686s 425ms/step - accuracy: 0.8498 - loss: 0.4125 - recall: 0.8691 - val_accuracy: 0.8471 - val_loss: 0.3364 - val_recall: 0.7221 - learning_rate: 1.0000e-04
# Epoch 2/15
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 660s 409ms/step - accuracy: 0.8606 - loss: 0.3920 - recall: 0.8774 - val_accuracy: 0.8698 - val_loss: 0.3145 - val_recall: 0.8087 - learning_rate: 1.0000e-04
# Epoch 3/15
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 567s 351ms/step - accuracy: 0.8688 - loss: 0.3698 - recall: 0.8810 - val_accuracy: 0.8725 - val_loss: 0.3094 - val_recall: 0.7704 - learning_rate: 1.0000e-04
# Epoch 4/15
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 550s 341ms/step - accuracy: 0.8748 - loss: 0.3495 - recall: 0.8891 - val_accuracy: 0.8919 - val_loss: 0.2863 - val_recall: 0.8369 - learning_rate: 1.0000e-04
# Epoch 5/15
# ...

# %%
base_model.trainable = True

# Bekukan sebagian awal layer, buka 30 layer terakhir
for layer in base_model.layers[:-30]:
    layer.trainable = False

# %%
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
#     loss="binary_crossentropy",
#     metrics=["accuracy"]
# )
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5), 
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Recall(name="recall")]
)

# %%
# history_fine = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=5
# )
# model.fit(train_ds, validation_data=val_ds, epochs=5)
history_finetune = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=5,
    callbacks=[lr_reducer, early_stop], 
    class_weight={0: 1.0, 1: 1.5}       
)
# Out:
# Epoch 1/5
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 638s 363ms/step - accuracy: 0.9271 - loss: 0.2131 - recall: 0.9349 - val_accuracy: 0.9039 - val_loss: 0.2534 - val_recall: 0.8486 - learning_rate: 1.0000e-05
# Epoch 2/5
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 546s 338ms/step - accuracy: 0.9298 - loss: 0.2036 - recall: 0.9376 - val_accuracy: 0.9032 - val_loss: 0.2551 - val_recall: 0.8569 - learning_rate: 1.0000e-05
# Epoch 3/5
# 1611/1612 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9254 - loss: 0.2144 - recall: 0.9352
# Epoch 3: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 548s 340ms/step - accuracy: 0.9305 - loss: 0.2053 - recall: 0.9386 - val_accuracy: 0.9032 - val_loss: 0.2552 - val_recall: 0.8453 - learning_rate: 1.0000e-05
# Epoch 4/5
# 1612/1612 ━━━━━━━━━━━━━━━━━━━━ 545s 338ms/step - accuracy: 0.9304 - loss: 0.2024 - recall: 0.9397 - val_accuracy: 0.9012 - val_loss: 0.2572 - val_recall: 0.8336 - learning_rate: 2.0000e-06
# ...

# %%
y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int).flatten()

    y_true.extend(labels.numpy())
    y_pred.extend(preds)

from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))

print("\n--- CLASSIFICATION REPORT MEDIS ---")
print(classification_report(y_true, y_pred, target_names=['NRG (Normal)', 'RG (Glaukoma)']))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ...

# %%
print("Train batches:", len(train_ds))
print("Validation batches:", len(val_ds))

# Hitung total gambar train
train_count = 0
for x, y in train_ds:
    train_count += x.shape[0]

val_count = 0
for x, y in val_ds:
    val_count += x.shape[0]

print("Total train images:", train_count)
print("Total validation images:", val_count)

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset/test",
    image_size=(224, 224),
    batch_size=16,
    label_mode="int",
    shuffle=False  # PENTING: jangan shuffle
)

print("\n--- Menghitung Skor Akhir di Data Test ---")
results = model.evaluate(test_ds)
print(f"Test Accuracy: {results[1]*100:.2f}%")
print(f"Test Recall: {results[2]*100:.2f}%")
# Out:
# Found 770 files belonging to 2 classes.
#
# --- Menghitung Skor Akhir di Data Test ---
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.9052 - loss: 0.2599 - recall: 0.9195
# Test Accuracy: 90.52%
# Test Recall: 91.95%

# %%
# test_loss, test_accuracy = model.evaluate(test_ds)
# print("Test Accuracy:", test_accuracy)

# %%
# y_true = []
# y_pred = []

# for images, labels in test_ds:
#     preds = model.predict(images)
#     preds = (preds > 0.5).astype(int).flatten()

#     y_true.extend(labels.numpy())
#     y_pred.extend(preds)

# print(confusion_matrix(y_true, y_pred))
# print(classification_report(y_true, y_pred))

y_true = []
y_pred = []

print("Memulai Inference Data Test Bersih... (Sabar, Dell-mu lagi kerja keras)")

# 2. Iterasi Dataset Test
for images, labels in test_ds:
    # Prediksi probabilitas (0.0 sampai 1.0)
    preds = model.predict(images, verbose=0) 
    

    binary_preds = (preds > 0.4).astype(int).flatten()
    
    y_true.extend(labels.numpy())
    y_pred.extend(binary_preds)

print("\n--- CONFUSION MATRIX (DATA TEST BERSIH) ---")
cm = confusion_matrix(y_true, y_pred)
print(cm)

print("\n--- REPORT EVALUASI FINAL ---")
print(classification_report(y_true, y_pred, target_names=['NRG (Normal)', 'RG (Glaukoma)']))
# Out:
# Memulai Inference Data Test Bersih... (Sabar, Dell-mu lagi kerja keras)
#
# --- CONFUSION MATRIX (DATA TEST BERSIH) ---
# [[330  55]
#  [ 27 358]]
#
# --- REPORT EVALUASI FINAL ---
#                precision    recall  f1-score   support
#
#  NRG (Normal)       0.92      0.86      0.89       385
# RG (Glaukoma)       0.87      0.93      0.90       385
#
#      accuracy                           0.89       770
#     macro avg       0.90      0.89      0.89       770
#  weighted avg       0.90      0.89      0.89       770

# %%
# EyePACS-TRAIN-RG-3269
# eyepac-light-v2-512-jpg

# img = image.load_img("eyepac-light-v2-512-jpg/test/RG/EyePACS-TRAIN-RG-3269.jpg", target_size=(224,224))
# img_array = image.img_to_array(img)
# img_array = np.expand_dims(img_array, axis=0)
# img_array = img_array / 255.0  

# prediction = model.predict(img_array)

# print("Probabilitas glaucoma:", prediction[0][0])

# if prediction[0][0] > 0.5:
#     print("Prediksi: Glaucoma (1)")
# else:
#     print("Prediksi: Tidak Glaucoma (0)")

# %%
model.save("glaucoma_model_v2.keras")
model.save("glaucoma_model_v2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# EyePACS-TRAIN-RG-3269
# eyepac-light-v2-512-jpg

img = image.load_img("picture/NRG/00001_n.png", target_size=(224,224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = img_array / 255.0  

prediction = model.predict(img_array)

print("Probabilitas glaucoma:", prediction[0][0])

if prediction[0][0] > 0.5:
    print("Prediksi: Glaucoma (1)")
else:
    print("Prediksi: Tidak Glaucoma (0)")

# %%
folder_path = "picture/glaucoma/"
file_names = os.listdir(folder_path)

print(f"Ditemukan {len(file_names)} file di folder {folder_path}\n")

for file_name in file_names:
    if file_name.endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(folder_path, file_name)
        
        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        
        prediction = model.predict(img_array, verbose=0) 
        probabilitas = prediction[0][0]

        status = "RG (Glaukoma)" if probabilitas > 0.5 else "NRG (Normal)"
        
        print(f"File: {file_name} | Skor: {probabilitas:.4f} | Hasil: {status}")
# Out:
# Ditemukan 385 file di folder picture/glaucoma/
#
# File: EyePACS-TRAIN-RG-2919.jpg | Skor: 0.9968 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-2960.jpg | Skor: 0.8676 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3051.jpg | Skor: 0.9750 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-2886.jpg | Skor: 0.9381 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3192.jpg | Skor: 0.6159 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-2996.jpg | Skor: 0.8940 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3106.jpg | Skor: 0.9983 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-2899.jpg | Skor: 0.9374 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3170.jpg | Skor: 0.9820 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-2940.jpg | Skor: 0.7896 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3154.jpg | Skor: 0.9988 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3055.jpg | Skor: 0.9981 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-RG-3069.jpg | Skor: 0.6276 | Hasil: RG (Glaukoma)
# ...

# %%
folder_path = "picture/noglaucoma/"
file_names = os.listdir(folder_path)

print(f"Ditemukan {len(file_names)} file di folder {folder_path}\n")

for file_name in file_names:
    if file_name.endswith(('.png', '.jpg', '.jpeg')):
        img_path = os.path.join(folder_path, file_name)
        

        img = image.load_img(img_path, target_size=(224, 224))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        

        prediction = model.predict(img_array, verbose=0) 
        probabilitas = prediction[0][0]
        

        status = "RG (Glaukoma)" if probabilitas > 0.5 else "NRG (Normal)"
        
        print(f"File: {file_name} | Skor: {probabilitas:.4f} | Hasil: {status}")
# Out:
# Ditemukan 385 file di folder picture/noglaucoma/
#
# File: EyePACS-TRAIN-NRG-3028.jpg | Skor: 0.0484 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3154.jpg | Skor: 0.0000 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3173.jpg | Skor: 0.0012 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-2904.jpg | Skor: 0.2829 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3195.jpg | Skor: 0.2546 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-2932.jpg | Skor: 0.4084 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3051.jpg | Skor: 0.7147 | Hasil: RG (Glaukoma)
# File: EyePACS-TRAIN-NRG-2902.jpg | Skor: 0.0304 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3252.jpg | Skor: 0.0000 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3127.jpg | Skor: 0.0000 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3254.jpg | Skor: 0.0001 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3170.jpg | Skor: 0.0640 | Hasil: NRG (Normal)
# File: EyePACS-TRAIN-NRG-3120.jpg | Skor: 0.0571 | Hasil: NRG (Normal)
# ...
